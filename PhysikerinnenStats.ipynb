# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import numpy as np

# %% [markdown]
# # Physikerinnen - Statistiken (1997-2020)

# %% [markdown]
# Die Daten kommen von [statistischen Bundesamt]().

# %% [markdown]
# ## Physikprofessorinnen

# %% [markdown]
# ### Data Loading

# %% [markdown]
# Daten werden von einem CSV File eingelesen und in der Liste `array` gespeichert.

# %%
import csv
with open('Data/21341-0003.csv', newline='') as f:
    reader = csv.reader(f, delimiter=';')
    array = []
    for row in reader:
        array.append(row)
        print(row)
# Out:
# ['GENESIS-Tabelle: 21341-0003']
# ['Professoren: Deutschland, Jahre, Fächergruppen, Geschlecht', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['Statistik des Hochschulpersonals', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['Deutschland', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['Professoren (Anzahl)', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '']
# ['', '', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
# ['Mathematik, Naturwissenschaften', 'männlich', '7085', '6873', '6880', '6779', '6786', '6959', '7183', '7251', '7198', '7043', '7013', '7094', '7251', '7354', '7508', '7549', '7617', '7628', '5302', '5248', '5208', '5179']
# ...

# %% [markdown]
# ### Data Wrangling and Cleaning

# %% [markdown]
# Nach der erste Inspektion der Daten wird klar, dass die gewuenschte Datensaetze in Reihe 5-8 von Zeile 2 bis 24 liegen. Die einzenen Eintraege muessen zudem noch von `str` (string) Format in den `int` (integer) Format umgewandelt werden.

# %%
x = array[5] # Years
x = x[2:24]
for i in range(0, len(x)): 
    x[i] = int(x[i])

# %%
y_male = array[6] # maennliche Naturwissenschaftler
y_male = y_male[2:24]
for i in range(0, len(y_male)): 
    y_male[i] = int(y_male[i])

# %%
y_female = array[7] # weibliche Naturwissenschaftler
y_female = y_female[2:24]
for i in range(0, len(y_female)): 
    y_female[i] = int(y_female[i])

# %%
y_total = array[8] # ingesamt
y_total = y_total[2:24]
for i in range(0, len(y_total)): 
    y_total[i] = int(y_total[i])

# %% [markdown]
# ### Data Plotting and Visualization

# %% [markdown]
# #### Total numbers in comparison

# %%
plt.plot(x,y_female,'-or', label='Frauenanteil')
plt.title('Frauenanteil der letzten Jahre')
plt.xlabel('Years')
plt.ylabel('Frauenanteil')

plt.legend();

# %%
plt.plot(x,y_male,'-ob', label='Maenneranteil')
plt.title('Maenneranteil der letzten Jahre')
plt.xlabel('Years')
plt.ylabel('Maenneranteil')

plt.legend();

# %%
plt.plot(x,y_total,'-og', label='Gesamtanzahl')
plt.title('Gesamtanteil der letzten Jahre')
plt.xlabel('Years')
plt.ylabel('Gesamtanteil')

plt.legend();

# %%
plt.plot(x,y_female,'-or', label='Frauenanteil')
plt.plot(x,y_male,'-ob', label='Maenneranteil')
plt.plot(x,y_total,'-og', label='Gesamtanzahl')
plt.title('Personenanteil der letzten Jahre')
plt.xlabel('Years')
plt.ylabel('Personenanteil')

plt.legend();

# %% [markdown]
# #### Relative numbers in comparison

# %%
y_femalep = []
for i in range(0, len(y_female)):
    y_femalep.append(y_female[i]/y_total[i]);
y_femalep;

# %%
y_malep = []
for i in range(0, len(y_male)):
    y_malep.append(y_male[i]/y_total[i]);
y_malep;

# %%
plt.plot(x,y_femalep,'-or', label='Frauenanteil')
plt.plot(x,y_malep,'-ob', label='Maenneranteil')
plt.title('Anteil innerhalb der letzten Jahre in Prozent')
plt.xlabel('Years')
plt.ylabel('Personenanteil')

plt.legend();
